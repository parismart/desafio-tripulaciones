# %%
import pandas as pd

# %%
df = pd.read_csv("data/puntos_interes.csv")

# %%
df = df.drop("Unnamed: 0", axis = 1)

# %%
extra_df = pd.read_csv("data/extra_df.csv")

# %%
df
# Out:
#                                            descripcion  \
# 0    Inici de la ruta, dominada per dos exemplars d...
# 1    En aquesta part intermèdia abans d’encarar l’A...
# 2    Últim tram de la ruta que no obstant això repr...
# 3    (Chamaerops humilis) En la Plaça del Ajuntamen...
# 4    En el Jardí de Sant Agustí es troba un lledone...
# ..                                                 ...
# 250  Aquest segon recorregut de la nostra ruta ho i...
# 251  Quasi enfronte tenim l’Església de Sant Lorenz...
# 252  A continuació tornarem al Carrer Salvador per ...
# 253  Molt prop d’aquesta església tenim l’Antic Sem...
# 254  Si baixem per la Plaza Conde del Real i seguim...
#
#                      coordenadas                     nombre_ruta  \
# 0    ['-0.3318938,39.4613464,0']             Arbres: Els indians
# 1    ['-0.3338142,39.4605098,0']             Arbres: Els indians
# 2      ['-0.3439986,39.46751,0']             Arbres: Els indians
# 3    ['-0.3766718,39.4697971,0']  Arbres monumentals i singulars
# 4    ['-0.3803908,39.4685944,0']  Arbres monumentals i singulars
# ..                           ...                             ...
# 250  ['-0.3747986,39.4777434,0']             Trinitat - L'Almodí
# 251  ['-0.3748737,39.4780332,0']             Trinitat - L'Almodí
# 252  ['-0.3739003,39.4770379,0']             Trinitat - L'Almodí
# 253   ['-0.374367,39.4766032,0']             Trinitat - L'Almodí
# 254  ['-0.3736777,39.4764914,0']             Trinitat - L'Almodí
#
#           nombre_punto_interes  \
# 0      Avinguda de J.J. Dómine
# 1           Drassanes del Grau
# 2                Jardí d'Aiora
# 3         Plaça del Ajuntament
# 4         Jardí de Sant Agustí
# ..                         ...
# 250         Palau de Benicarló
# 251  Església de Sant Lorenzo
# 252      Església del Salvador
# 253             Antic Seminari
# 254                   L’Almodí
#
#                                       descripcion_ruta
# 0    La presència d’Arbres Monumentals i Singulars ...
# 1    La presència d’Arbres Monumentals i Singulars ...
# 2    La presència d’Arbres Monumentals i Singulars ...
# 3    La presència d’Arbres Monumentals i Singulars ...
# 4    La presència d’Arbres Monumentals i Singulars ...
# ..                                                 ...
# 250  La ruta compresa entre el Monestir de la Trini...
# 251  La ruta compresa entre el Monestir de la Trini...
# 252  La ruta compresa entre el Monestir de la Trini...
# 253  La ruta compresa entre el Monestir de la Trini...
# 254  La ruta compresa entre el Monestir de la Trini...
#
# [255 rows x 5 columns]

# %%
# extra_df

# %%
extra_df = extra_df.rename(columns={"descripcion_ruta": "descripcion", "descripcion": "descripcion_ruta"})

# %%
cols = list(extra_df.columns)
cols
# Out:
# ['descripcion_ruta',
#  'coordenadas',
#  'nombre_ruta',
#  'nombre_punto_interes',
#  'descripcion']

# %%
cols = ['descripcion',
 'coordenadas',
 'nombre_ruta',
 'nombre_punto_interes',
 'descripcion_ruta']

# %%
extra_df = extra_df[cols]

# %%
full_df = pd.concat([df,extra_df]).reset_index(drop=True)

# %%
full_df
# Out:
#                                            descripcion  \
# 0    Inici de la ruta, dominada per dos exemplars d...
# 1    En aquesta part intermèdia abans d’encarar l’A...
# 2    Últim tram de la ruta que no obstant això repr...
# 3    (Chamaerops humilis) En la Plaça del Ajuntamen...
# 4    En el Jardí de Sant Agustí es troba un lledone...
# ..                                                 ...
# 263  Les flors d'aquesta fita moderna es substituei...
# 264  Lloc per a actuacions d'orquestra, concerts i ...
# 265  Complex científic d'última generació situat en...
# 266  L'antic port de la ciutat avui és la Marina de...
# 267  El Passeig Marítim de València comença al cost...
#
#                                    coordenadas  \
# 0                  ['-0.3318938,39.4613464,0']
# 1                  ['-0.3338142,39.4605098,0']
# 2                    ['-0.3439986,39.46751,0']
# 3                  ['-0.3766718,39.4697971,0']
# 4                  ['-0.3803908,39.4685944,0']
# ..                                         ...
# 263  [-0.36430827529787013, 39.47138706943263]
# 264   [-0.3601494599556288, 39.46642106701521]
# 265  [-0.35047967344916114, 39.45508217932197]
# 266   [-0.3299127577646471, 39.46164343064316]
# 267  [-0.32449228879096537, 39.47473736753662]
#
#                         nombre_ruta               nombre_punto_interes  \
# 0               Arbres: Els indians            Avinguda de J.J. Dómine
# 1               Arbres: Els indians                 Drassanes del Grau
# 2               Arbres: Els indians                      Jardí d'Aiora
# 3    Arbres monumentals i singulars               Plaça del Ajuntament
# 4    Arbres monumentals i singulars               Jardí de Sant Agustí
# ..                              ...                                ...
# 263     Ruta València amb bicicleta                  Pont de les flors
# 264     Ruta València amb bicicleta     Palau de la Música de València
# 265     Ruta València amb bicicleta  Ciutat de les Arts i les Ciències
# 266     Ruta València amb bicicleta              La Marina de València
# 267     Ruta València amb bicicleta        Passeig Marítim de València
#
#                                       descripcion_ruta
# 0    La presència d’Arbres Monumentals i Singulars ...
# 1    La presència d’Arbres Monumentals i Singulars ...
# 2    La presència d’Arbres Monumentals i Singulars ...
# 3    La presència d’Arbres Monumentals i Singulars ...
# 4    La presència d’Arbres Monumentals i Singulars ...
# ..                                                 ...
# 263  Si apostes pel transport sostenible i t'agrada...
# 264  Si apostes pel transport sostenible i t'agrada...
# 265  Si apostes pel transport sostenible i t'agrada...
# 266  Si apostes pel transport sostenible i t'agrada...
# 267  Si apostes pel transport sostenible i t'agrada...
#
# [268 rows x 5 columns]

# %%
cols = ['nombre_ruta', 'nombre_punto_interes', 'descripcion', 'coordenadas','descripcion_ruta']

# %%
full_df = full_df[cols]

# %%
full_df
# Out:
#                         nombre_ruta               nombre_punto_interes  \
# 0               Arbres: Els indians            Avinguda de J.J. Dómine
# 1               Arbres: Els indians                 Drassanes del Grau
# 2               Arbres: Els indians                      Jardí d'Aiora
# 3    Arbres monumentals i singulars               Plaça del Ajuntament
# 4    Arbres monumentals i singulars               Jardí de Sant Agustí
# ..                              ...                                ...
# 263     Ruta València amb bicicleta                  Pont de les flors
# 264     Ruta València amb bicicleta     Palau de la Música de València
# 265     Ruta València amb bicicleta  Ciutat de les Arts i les Ciències
# 266     Ruta València amb bicicleta              La Marina de València
# 267     Ruta València amb bicicleta        Passeig Marítim de València
#
#                                            descripcion  \
# 0    Inici de la ruta, dominada per dos exemplars d...
# 1    En aquesta part intermèdia abans d’encarar l’A...
# 2    Últim tram de la ruta que no obstant això repr...
# 3    (Chamaerops humilis) En la Plaça del Ajuntamen...
# 4    En el Jardí de Sant Agustí es troba un lledone...
# ..                                                 ...
# 263  Les flors d'aquesta fita moderna es substituei...
# 264  Lloc per a actuacions d'orquestra, concerts i ...
# 265  Complex científic d'última generació situat en...
# 266  L'antic port de la ciutat avui és la Marina de...
# 267  El Passeig Marítim de València comença al cost...
#
#                                    coordenadas  \
# 0                  ['-0.3318938,39.4613464,0']
# 1                  ['-0.3338142,39.4605098,0']
# 2                    ['-0.3439986,39.46751,0']
# 3                  ['-0.3766718,39.4697971,0']
# 4                  ['-0.3803908,39.4685944,0']
# ..                                         ...
# 263  [-0.36430827529787013, 39.47138706943263]
# 264   [-0.3601494599556288, 39.46642106701521]
# 265  [-0.35047967344916114, 39.45508217932197]
# 266   [-0.3299127577646471, 39.46164343064316]
# 267  [-0.32449228879096537, 39.47473736753662]
#
#                                       descripcion_ruta
# 0    La presència d’Arbres Monumentals i Singulars ...
# 1    La presència d’Arbres Monumentals i Singulars ...
# 2    La presència d’Arbres Monumentals i Singulars ...
# 3    La presència d’Arbres Monumentals i Singulars ...
# 4    La presència d’Arbres Monumentals i Singulars ...
# ..                                                 ...
# 263  Si apostes pel transport sostenible i t'agrada...
# 264  Si apostes pel transport sostenible i t'agrada...
# 265  Si apostes pel transport sostenible i t'agrada...
# 266  Si apostes pel transport sostenible i t'agrada...
# 267  Si apostes pel transport sostenible i t'agrada...
#
# [268 rows x 5 columns]

# %%
full_df["list_coor"] = full_df["coordenadas"].str.replace("[","").str.replace("]","").str.split(",")
# Out:
# C:\Users\gabri\AppData\Local\Temp/ipykernel_2640/3306823465.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   full_df["list_coor"] = full_df["coordenadas"].str.replace("[","").str.replace("]","").str.split(",")
# C:\Users\gabri\AppData\Local\Temp/ipykernel_2640/3306823465.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df["list_coor"] = full_df["coordenadas"].str.replace("[","").str.replace("]","").str.split(",")

# %%
full_df["lat"] = full_df["list_coor"].str[0].str.replace("'","")
# Out:
# C:\Users\gabri\AppData\Local\Temp/ipykernel_2640/1088416254.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df["lat"] = full_df["list_coor"].str[0].str.replace("'","")

# %%
full_df["lat"] = full_df["lat"].astype("float32")
# Out:
# C:\Users\gabri\AppData\Local\Temp/ipykernel_2640/1827927609.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df["lat"] = full_df["lat"].astype("float32")

# %%
full_df["long"] = full_df["list_coor"].str[1]
# Out:
# C:\Users\gabri\AppData\Local\Temp/ipykernel_2640/1127439077.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df["long"] = full_df["list_coor"].str[1]

# %%
full_df["long"] = full_df["long"].astype("float32")
# Out:
# C:\Users\gabri\AppData\Local\Temp/ipykernel_2640/2554612429.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df["long"] = full_df["long"].astype("float32")

# %%
full_df = full_df.drop(columns=["coordenadas","list_coor"])

# %%
full_df = full_df.drop(columns="descripcion_ruta")

# %%
full_df
# Out:
#                         nombre_ruta               nombre_punto_interes  \
# 0               Arbres: Els indians            Avinguda de J.J. Dómine
# 1               Arbres: Els indians                 Drassanes del Grau
# 2               Arbres: Els indians                      Jardí d'Aiora
# 3    Arbres monumentals i singulars               Plaça del Ajuntament
# 4    Arbres monumentals i singulars               Jardí de Sant Agustí
# ..                              ...                                ...
# 263     Ruta València amb bicicleta                  Pont de les flors
# 264     Ruta València amb bicicleta     Palau de la Música de València
# 265     Ruta València amb bicicleta  Ciutat de les Arts i les Ciències
# 266     Ruta València amb bicicleta              La Marina de València
# 267     Ruta València amb bicicleta        Passeig Marítim de València
#
#                                            descripcion       lat       long
# 0    Inici de la ruta, dominada per dos exemplars d... -0.331894  39.461346
# 1    En aquesta part intermèdia abans d’encarar l’A... -0.333814  39.460510
# 2    Últim tram de la ruta que no obstant això repr... -0.343999  39.467510
# 3    (Chamaerops humilis) En la Plaça del Ajuntamen... -0.376672  39.469795
# 4    En el Jardí de Sant Agustí es troba un lledone... -0.380391  39.468594
# ..                                                 ...       ...        ...
# 263  Les flors d'aquesta fita moderna es substituei... -0.364308  39.471386
# 264  Lloc per a actuacions d'orquestra, concerts i ... -0.360149  39.466419
# 265  Complex científic d'última generació situat en... -0.350480  39.455082
# 266  L'antic port de la ciutat avui és la Marina de... -0.329913  39.461643
# 267  El Passeig Marítim de València comença al cost... -0.324492  39.474739
#
# [268 rows x 5 columns]

# %%
full_df.to_csv("data/clean_points_of_routes.csv ")

# %%
full_df = pd.read_csv("data/clean_points_of_routes.csv")

# %%
full_df["nombre_ruta"].unique()
# Out:
# array(['Arbres: Els indians', 'Arbres monumentals i singulars',
#        'Arbres: Un passeig per l’Albereda',
#        'Contes Blasco Ibañez – Ruta 1', 'Contes Blasco Ibañez – Ruta 2',
#        'Entre Naranjos', 'Glorieta-Santa Catalina',
#        'Jardins del Reial - Glorieta', 'La barraca',
#        'Ruta Carrer Russafa - la Llotja', 'Ruta Cultural Anell Ciclista',
#        'Ruta de la Seda',
#        "Ruta dels Pecats a l'entorn del Mercat Central",
#        'Ruta pel Centre Històric', 'Ruta Valencia en la Memòria',
#        'Sant Agustí - Portal Nou', 'Sant Agustí – Pont de Fusta',
#        'Serrans - Palau de la Generalitat', 'Torres de Quart - Temple',
#        "Trinitat - L'Almodí", 'Ruta València amb bicicleta'], dtype=object)
