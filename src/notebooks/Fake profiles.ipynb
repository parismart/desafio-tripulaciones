# %%
# !pip install faker

# %%
pip install sdv
# Out:
# ...
#
# ...
#   Using cached scipy-1.7.3-cp38-cp38-win_amd64.whl (34.2 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.1
#     Uninstalling numpy-1.23.1:
#       Successfully uninstalled numpy-1.23.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.8.1
#     Uninstalling scipy-1.8.1:
#       Successfully uninstalled scipy-1.8.1
#   Attempting uninstall: Faker
#     Found existing installation: Faker 13.15.0
#     Uninstalling Faker-13.15.0:
#       Successfully uninstalled Faker-13.15.0
# ...

# %%
pip install gretel-synthetics
# Out:
# ...
#   Using cached importlib_resources-5.8.0-py3-none-any.whl (28 kB)
# ...
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21503 sha256=69680817367f851d3048883adf455dc7b020e7e13c0e2cfeb6b309da341197ad
#   Stored in directory: c:\users\rafi\appdata\local\pip\cache\wheels\54\aa\01\724885182f93150035a2a91bce34a12877e8067a97baaf5dc8
# ...
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4848 sha256=4ce4cc77719759444be2acfd9edeef34ac3d8a6e49dcad4f4fcd84c8707563e3
#   Stored in directory: c:\users\rafi\appdata\local\pip\cache\wheels\a0\16\9c\5473df82468f958445479c59e784896fa24f4a5fc024b0f501
# Successfully built promise termcolor
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install pycountry
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681832 sha256=0b627966306a225d8870ad07ca556f8e20d61faf6e2db1c61f45125f59fb5124
#   Stored in directory: c:\users\rafi\appdata\local\pip\cache\wheels\e2\aa\0f\c224e473b464387170b83ca7c66947b4a7e33e8d903a679748
# Successfully built pycountry
# ...

# %%
import pycountry
import faker

# %%
# Out:
# Type:        module
# String form: <module 'pycountry' from 'c:\\Users\\Rafi\\Anaconda3\\envs\\aws_evn\\lib\\site-packages\\pycountry\\__init__.py'>
# File:        c:\users\rafi\anaconda3\envs\aws_evn\lib\site-packages\pycountry\__init__.py
# Docstring:   pycountry

# %%
import pandas as pd
import numpy as np
from faker import Faker

# create some fake data
fake = Faker()

# function to create a dataframe with fake values for our workers
def make_workers(num):
    
    # lists to randomly assign to workers
    ou_list = ['Master', 'FP','Graduado/Lic','PHd/Doctor','Sin estudios']
    gender_list = ['M', 'F']
    country_list = ['Albania', 'Andorra', 'Armenia', 'Austria', 'Azerbaijan', 'Belarus', 'Belgium','Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Cyprus',\
                'Czech Republic', 'Denmark', 'Denmark', 'Estonia', 'Finland', 'France', 'Georgia', 'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy'\
                'Kazakhstan', 'Latvia', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macedonia', 'Malta', 'Moldova', 'Monaco', 'Montenegro', 'Netherlands',\
                'Norway', 'Poland', 'Portugal', 'Romania', 'Russia', 'San Marino', 'Serbia', 'Slovakia', 'Slovenia', 'Spain', 'Sweden', 'Switzerland',\
                'Turkey', 'Ukraine', 'United Kingdom', 'Vatican City']

    language_list = ['english','french','spanish','german','dutch']
    grade_list = ['Senior Associate','Manager','Associate','Junior','Senior Manager']
    #careerinterests_list = ['solutions design','pm','azure','python','.net','javascript','sql']

    fake_workers = [{'User-Id':np.random.randint(1,10000000),
        'name':fake.name(), 
        'age':np.random.randint(25,55),
        #'los': 'IFS',
        'ou': np.random.choice(ou_list),
        'gender': np.random.choice(gender_list),
        'country': np.random.choice(country_list),
        'language': np.random.choice(language_list),
        'grade': np.random.choice(grade_list),
        #'career interests': np.random.choice(careerinterests_list)
     }]
        
    return fake_workers

worker_df = pd.DataFrame(make_workers(num=1))

i=1
while i < 8000:
    worker_df = worker_df.append(pd.DataFrame(make_workers(num=1)))
    i += 1

worker_df
# Out:
# C:\Users\Rafi\AppData\Local\Temp\ipykernel_25524\3430688508.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   worker_df = worker_df.append(pd.DataFrame(make_workers(num=1)))
# C:\Users\Rafi\AppData\Local\Temp\ipykernel_25524\3430688508.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   worker_df = worker_df.append(pd.DataFrame(make_workers(num=1)))
# C:\Users\Rafi\AppData\Local\Temp\ipykernel_25524\3430688508.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   worker_df = worker_df.append(pd.DataFrame(make_workers(num=1)))
# ...
